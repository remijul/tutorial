# %% [markdown]
# <a href="https://colab.research.google.com/github/remijul/tutorial/blob/master/Getting_started_with_Seaborn_Part_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Getting started with Seaborn - Part 1
# Seaborn is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics.
#
# ![Python_logo.png](data:image/png;base64,...)
#
#
# ---

# %% [markdown]
# ### Import librairies

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# %% [markdown]
# ### Load data

# %%
url = "https://opendata.arcgis.com/datasets/6f64bbd4f94c425791c2ec7eee33bb71_0.csv"
df = pd.read_csv(url)
df.head()
# Out:
#           X          Y                date_ech  ...   x_wgs84    y_wgs84 ObjectId
# 0  1.903984  47.903174  2019/01/02 00:00:00+00  ...  1.903984  47.903174        1
# 1  0.682860  47.394438  2018/10/14 00:00:00+00  ...  0.682860  47.394438        2
# 2  2.396232  47.079706  2019/01/02 00:00:00+00  ...  2.396232  47.079706        3
# 3  1.490599  48.445544  2018/10/20 00:00:00+00  ...  1.490599  48.445544        4
# 4  1.696049  46.810434  2018/10/20 00:00:00+00  ...  1.696049  46.810434        5
#
# [5 rows x 18 columns]

# %% [markdown]
# ## Categorical plot
# ### Bar plot

# %%
sns.catplot(x="lib_zone", y="valeur", kind="bar", data=df)#, hue="qualif", col="qualif", col_wrap=2)

# %%
sns.catplot(x="lib_zone", y="valeur", kind="bar", data=df, hue="qualif", col="qualif", col_wrap=3)

# %%
sns.catplot(y="lib_zone", x="valeur", kind="bar", data=df, hue="qualif", col="qualif", col_wrap=3)

# %% [markdown]
# ###Boxplot

# %%
sns.catplot(y="lib_zone", x="valeur", kind="box", data=df)

# %%
sns.catplot(y="lib_zone", x="valeur", kind="box", data=df.query("valeur >= 5"))

# %% [markdown]
# ## Quantitative data
# ### Relational plot

# %%
plt.figure(figsize=(12, 8))
sns.relplot(x="date_ech", y="valeur", kind="line", data=df)

# %%
plt.figure(figsize=(12, 8))
sns.relplot(x="date_ech", y="valeur", kind="line", data=df.query("date_ech >= '2018/07/01 00:00:00+00' & date_ech < '2019/01/01 00:00:00+00'"))

# %%
plt.figure(figsize=(12, 8))
sns.relplot(x="date_ech", y="valeur", kind="line", hue="lib_zone",
            data=df.query("date_ech >= '2018/07/01 00:00:00+00' & date_ech < '2019/01/01 00:00:00+00'"))

# %%
plt.figure(figsize=(20, 16))
sns.relplot(x="date_ech", y="valeur", kind="line", hue="lib_zone", col="lib_zone", col_wrap=3,
            data=df.query("date_ech >= '2018/07/01 00:00:00+00' & date_ech < '2019/01/01 00:00:00+00'"))

# %% [markdown]
# ## Exercices
#
# ![your_turn_gatsby.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# The goal of this exercice is to :
# -
# -
# -

# %%
# Your turn here

# %% [markdown]
# ## Ressources
# - The official Seaborn' [user guide and tutorial](https://seaborn.pydata.org/tutorial.html)

# %% [markdown]
# ---
# Did you love it ? [Please visit my website](http://www.dcid-consulting.fr/) and lets' get in touch for special needs : consultancy, dedicated training, cut-in-the-edge development, etc.
# ![logo_web.png](data:image/png;base64,...)
# Data science | Machine learning | Data analytics | Dataviz
